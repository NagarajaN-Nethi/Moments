# %% [markdown]
# <a href="https://colab.research.google.com/github/NagarajaN-Nethi/Moments/blob/master/Calculate_Moments%2C_Kurtosis_and_Skewness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def moments(df):
  from scipy.stats import moment, kurtosis
  from scipy.stats import skew
  import pandas as pd
  mu1 = []
  mu2 = []
  mu3 = []
  mu4 = []
  for i in df.columns:
    mu1.append(moment(df[i], moment = 1))
    mu2.append(moment(df[i], moment = 2))
    mu3.append(moment(df[i], moment = 3))
    mu4.append(moment(df[i], moment = 4))
  mu1 = pd.DataFrame(mu1)
  mu2 = pd.DataFrame(mu2)
  mu3 = pd.DataFrame(mu3)
  mu4 = pd.DataFrame(mu4)
  kurtosis1 = kurtosis(data, fisher = False)
  kurtosis1 = pd.DataFrame(kurtosis1)
  skewness = skew(data, axis = 0).reshape(15, 1)
  skewness = pd.DataFrame(skewness)
  moments = pd.concat((mu1, mu2, mu3, mu4, kurtosis1, skewness),axis = 1)
  moments.columns = ['mu1', 'mu2', 'mu3', 'mu4', 'kurtosis', 'skewness']
  moments.to_csv('moments.csv')
  return moments

# %%
moments(data)
# Out:
#     mu1          mu2           mu3           mu4  kurtosis  skewness
# 0   0.0  1777.824026  -9034.759643  7.225230e+06  2.285989 -0.120527
# 1   0.0  1597.816543  20968.091190  7.302616e+06  2.860386  0.328298
# 2   0.0  2265.734391 -20795.816487  1.287434e+07  2.507881 -0.192825
# 3   0.0  2044.788406   9264.636699  1.060810e+07  2.537119  0.100197
# 4   0.0  1634.963829  -1141.673232  6.631156e+06  2.480693 -0.017269
# 5   0.0  2367.913100   6822.876842  1.267235e+07  2.260090  0.059213
# 6   0.0  2036.091894  -1894.922780  9.891859e+06  2.386070 -0.020625
# 7   0.0  2086.225110 -25422.188721  1.077725e+07  2.476199 -0.266791
# 8   0.0  2440.885531 -26923.498413  1.448468e+07  2.431163 -0.223260
# 9   0.0  2212.040522  14523.027830  1.202961e+07  2.458473  0.139594
# 10  0.0  1968.482108   5109.657938  8.648565e+06  2.231933  0.058505
# 11  0.0  2196.144166   7060.042007  1.044137e+07  2.164889  0.068599
# 12  0.0  1997.092699   4621.004476  9.452151e+06  2.369923  0.051777
# ...
